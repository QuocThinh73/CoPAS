# %%
# !git clone https://github.com/QuocThinh73/CoPAS.git
# Out:
# Cloning into 'CoPAS'...
# remote: Enumerating objects: 107, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 107 (delta 52), reused 59 (delta 23), pack-reused 0 (from 0)
# Receiving objects: 100% (107/107), 47.48 KiB | 11.87 MiB/s, done.
# Resolving deltas: 100% (52/52), done.

# %%
# %cd CoPAS
# Out:
# /content/CoPAS

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 65.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.6/393.6 kB 28.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 15.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 67.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.2 MB/s eta 0:00:00
# ...

# %%
# !gdown 1yI_og5jIZQ2mTHvFyBsz9o4a_3RzBBHR
# !gdown 1WlvCoqFHQPS4kwU8sXdNhfXAd31NzKDy
# !gdown 11CjHCIA97EyvIruCbzG3SZelgl-FSwOa
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1yI_og5jIZQ2mTHvFyBsz9o4a_3RzBBHR
# From (redirected): https://drive.google.com/uc?id=1yI_og5jIZQ2mTHvFyBsz9o4a_3RzBBHR&confirm=t&uuid=9b10f3b9-0397-4819-bbeb-bd7dff5757c1
# To: /content/CoPAS/model.pth
# 100% 684M/684M [00:07<00:00, 96.0MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1WlvCoqFHQPS4kwU8sXdNhfXAd31NzKDy
# From (redirected): https://drive.google.com/uc?id=1WlvCoqFHQPS4kwU8sXdNhfXAd31NzKDy&confirm=t&uuid=a1849556-acb0-489b-805c-6dff076af8ef
# To: /content/CoPAS/SampleData.zip
# 100% 1.42G/1.42G [00:26<00:00, 52.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=11CjHCIA97EyvIruCbzG3SZelgl-FSwOa
# To: /content/CoPAS/samplelabels.csv
# 100% 1.66k/1.66k [00:00<00:00, 8.18MB/s]

# %%
# !unzip SampleData.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: SampleData/MR60236/cor T1WI/IMG-0004-00041.dcm
#   inflating: SampleData/MR60236/cor T1WI/IMG-0004-00042.dcm
#    creating: SampleData/MR60236/sag PDW/
#   inflating: SampleData/MR60236/sag PDW/.DS_Store
#   inflating: SampleData/MR60236/sag PDW/IMG-0002-00001.dcm
#   inflating: SampleData/MR60236/sag PDW/IMG-0002-00002.dcm
#   inflating: SampleData/MR60236/sag PDW/IMG-0002-00003.dcm
#   inflating: SampleData/MR60236/sag PDW/IMG-0002-00004.dcm
#   inflating: SampleData/MR60236/sag PDW/IMG-0002-00005.dcm
#   inflating: SampleData/MR60236/sag PDW/IMG-0002-00006.dcm
#   inflating: SampleData/MR60236/sag PDW/IMG-0002-00007.dcm
#   inflating: SampleData/MR60236/sag PDW/IMG-0002-00008.dcm
#   inflating: SampleData/MR60236/sag PDW/IMG-0002-00009.dcm
#   inflating: SampleData/MR60236/sag PDW/IMG-0002-00010.dcm
#   inflating: SampleData/MR60236/sag PDW/IMG-0002-00011.dcm
# ...

# %%
# %cd main
# Out:
# /content/CoPAS/main

# %%
# !python run.py --test --weight_path /content/CoPAS/model.pth
# Out:
# initiating
# 2025-04-30 16:14:16.819339: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746029656.840784   10351 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746029656.847276   10351 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-30 16:14:16.868773: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
